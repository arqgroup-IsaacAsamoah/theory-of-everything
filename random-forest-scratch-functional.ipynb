# %% [markdown]
# # Random forest regression
#
# ### Training
# * Set number of trees = B
# * Set tree depth rule = terminal node partition size >=5
# * Take a bootstrap sample from given data
# * Build a random forest tree
#     * Set the sample size for the feature sample, start with m = sqrt(p)
#
#     * Take a random sample m of input features from the feature set p
#
#     * For each feature selected define cutpoints to be assessed for partitioning the feature space. Method investigation required.
#
#     * For each feature (p) - cutpoint (s) combination partition the data and calculate the mean of both partitions.
#
#     * Calculate the combined RSS of both partitions
#
#     * Select and store the feature - cutpoint combination with minnimum combined RSS of both partitions. Also store the mean of each partition.
#
#     * Apply the same random forest partition steps for each new partition until the tree depth rule is violated. That is, each new partition is treated the same as the original data and partitioned by the same rules.
#
#     * Store the tree as the list of selected partitions and the out of bag R2 and MSE for the tree
#
# * Repeat the random forest steps until the  number of random froest trees = B
# * Store thje Random forest as a set of random forest trees.
# * Once the number of random forest trees = B, for each observation in the training data, predict the outcome using the trees for which the observation is out-of-bag.
#     * To predict the outcome, apply the store partitions for each tree to the feature space of the observation.
#     * Take the mean of the terminal node the observation is placed in for each tree
#     * Take the mean of the predicted outcome for each tree.
#     * This mean of the means is the prediction for that observation.
# * Using the OOB prediction of each outcome, calculate the OOB MSE and R2 for the random forest.
# * Store the OOB MSE and R2 for the Random forest
# * Uing the stored training predictions, calculate the training MSE and R2
# * Store the training MSE and R2 for the Random forest
#
# ### Testing
# * for each observation of the test set:
#     * partition the feature space acording to the random forest model provided
#     * Calculate the mean of the terminal node for each tree
#     * take the mean of the prediction across all trees in the forest
# * From the predicted values calculate the test MSE and R2.

# %% [markdown]
# ### To do
# * R2 function
# * MSE function
# * change interface to recieve y and X separately at all levels (update bootstrap function)
# * Out of bag error and R2 optional helper function in grow_forest
# * Cross validation function for using growing and assessing random forests
# * priune tree function to find the best subttree when penalised for complexity

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import random as rand
import math

# %%
# training data
y = datasets.load_boston()['target']
X = datasets.load_boston()['data']
columns = datasets.load_boston()['feature_names']
data = pd.DataFrame(X)
data.columns = columns
data.loc[:, 'y'] = y

train = data.sample(frac =0.7)
test = data[~data.isin(train)].dropna()

display(train)
display(test)
# Out:
#          CRIM    ZN  INDUS  CHAS     NOX     RM    AGE     DIS   RAD    TAX  \
# 440  22.05110   0.0  18.10   0.0  0.7400  5.818   92.4  1.8662  24.0  666.0
# 168   2.30040   0.0  19.58   0.0  0.6050  6.319   96.1  2.1000   5.0  403.0
# 450   6.71772   0.0  18.10   0.0  0.7130  6.749   92.6  2.3236  24.0  666.0
# 434  13.91340   0.0  18.10   0.0  0.7130  6.208   95.0  2.2222  24.0  666.0
# 205   0.13642   0.0  10.59   0.0  0.4890  5.891   22.3  3.9454   4.0  277.0
# 136   0.32264   0.0  21.89   0.0  0.6240  5.942   93.5  1.9669   4.0  437.0
# 69    0.12816  12.5   6.07   0.0  0.4090  5.885   33.0  6.4980   4.0  345.0
# 269   0.09065  20.0   6.96   1.0  0.4640  5.920   61.5  3.9175   3.0  223.0
# 334   0.03738   0.0   5.19   0.0  0.5150  6.310   38.5  6.4584   5.0  224.0
# 220   0.35809   0.0   6.20   1.0  0.5070  6.951   88.5  2.8617   8.0  307.0
# 169   2.44953   0.0  19.58   0.0  0.6050  6.402   95.2  2.2625   5.0  403.0
# 89      17.8  396.06   5.70  28.7
# 90      17.8  392.18   8.81  22.6
# 93      18.2  396.33   6.21  25.0
# 99      18.0  396.90   6.19  33.2
# 102     20.9   70.80  10.63  18.6
# 116     17.8  393.30  12.04  21.2
# ..       ...     ...    ...   ...
# 389     20.2  396.90  20.85  11.5
# 391     20.2  378.38  18.76  23.2
# 392     20.2  396.90  25.68   9.7
# 400     20.2  396.90  26.77   5.6
# 404     20.2  329.46  27.38   8.5
# 406     20.2  370.22  23.34  11.9
# 416     20.2   21.57  25.79   7.5
# 418     20.2   16.45  20.62   8.8
# 419     20.2   48.45  22.74   8.4
# 423     20.2    2.52  23.29  13.4
# 430     20.2   83.45  17.64  14.5
# 431     20.2   81.33  19.69  14.1
# 435     20.2  109.85  23.27  13.4
# 437     20.2    9.32  26.45   8.7
# 442     20.2  395.69  16.59  18.4
# 447     20.2  388.52  16.44  12.6
# 448     20.2  396.90  18.13  14.1
# 449     20.2  304.21  19.31  13.0
# 455     20.2   50.92  18.13  14.1
# 460     20.2  255.23  16.42  16.4
# 462     20.2  396.90  13.99  19.5
# 464     20.2  396.90  13.22  21.4
# 465     20.2  334.40  14.13  19.9
# 468     20.2  368.74  18.13  19.1
# 473     20.2  374.68  11.66  29.8
# 476     20.2  396.21  18.68  16.7
# 487     20.2  388.22  11.45  20.6
# 489     20.1  344.05  23.97   7.0
# 491     20.1  390.11  18.07  13.6
# 504     21.0  393.45   6.48  22.0
#
# [152 rows x 14 columns]

# %%
# tiny small data for tree by hand
# tiny small data for tree by hand
np.random.seed(0)
toy_data = pd.DataFrame({'a' : np.random.choice(57, 10), 'c' : np.random.choice(11, 10),
                         'y' : np.random.choice(78, 10)})
y_toy = toy_data.loc[:,'y']
X_toy = toy_data.loc[:, ['a', 'c']]
toy_data
# Out:
#     a   c   y
# 0  44   2  46
# 1  47   4  37
# 2  53   7  25
# 3   0   6  77
# 4   3   8  72
# 5   3   8   9
# 6  39  10  20
# 7   9   1  69
# 8  19   6  47
# 9  21   7  64

# %%
# tiny data for testing tree by hand
np.random.seed(1)
toy_data_test = pd.DataFrame({'a' : np.random.choice(89, 10), 'c' : np.random.choice(45, 10),
                         'y' : np.random.choice(23, 10)})

# %%
# feature partitioning

def get_feature_splits(y, f):
   
    '''split the y variable by split s in feature f'''
    
    return ([{'feature' : f.name, 'split' :  s, 'left': y[f < s],
              'right' :  y[f >= s]} for s in f])

# %%
def combined_RSS(y1, y2):
    
    '''calculate the combined residual sum of squares for y1 and y1'''
    
    return np.sum((y1 - np.mean(y1))**2) + np.sum((y2 - np.mean(y2))**2)

# %%
# cost function

def cost_function(feature_split): 
    
    '''calculate the total RSS for the splits defined by splitting feature f at split s'''
    
    return ({'feature' : feature_split['feature'],
              'split' : feature_split['split'],
              'cost' : combined_RSS(feature_split['left'], feature_split['right'])
            }
           )

# %%
def flatten_list(l):
    return [item for sublist in l for item in sublist]

# %%
# partitioning y for each feature split combination

def get_split_costs(df):
    
    '''calulate the cost for each split'''
    
    return flatten_list(
        [[cost_function(split) for split in get_feature_splits(
            df.iloc[:,-1], df.iloc[:,:-1].loc[:, feature])] for feature in rand.sample(list(
            df.iloc[:,:-1].columns), int(math.sqrt(len(list(df.iloc[:,:-1].columns)))))])

# %%
def select_node(split_costs): 
    
    
    '''select the lowest cost node'''
    
    return (rand.choice([{'feature' : split['feature'], 'split' : split['split'],
                          'cost' : split['cost']}
                         for split in split_costs if split['cost'] == np.min(
                             [split['cost'] for split in split_costs])]))

# %%
def terminal_node(node_y):
    
    '''return the prediction for the terminal node'''
    
    return np.mean(node_y)

# %%
def grow_tree(df, node, depth, max_depth = 1, min_size = 5 ):
    
    ''' recursively grow a decision tree by applying the function to each node it 
    returns until max depth of min size criteria is met '''
    
    left = df.loc[df.loc[:, node['feature']] < node['split']]
    right = df.loc[df.loc[:, node['feature']] >= node['split']]
    
    if left.empty or right.empty:
        return terminal_node(list(left.iloc[:, -1]) + list(right.iloc[:, -1]))
        
    elif depth >= max_depth:
        return {'node': node, 
                'left': terminal_node(left.iloc[:, -1]), 
                'right': terminal_node(right.iloc[:, -1])}
    
    else:
        return {'node' : node,
                
                'left' : (lambda x: terminal_node(list(x.iloc[:, -1])) 
                          if len(x.iloc[:, -1]) <= min_size
                          else grow_tree(x, select_node(get_split_costs(x)),
                                        depth + 1, max_depth, min_size))(left),
                
                'right' : (lambda x: terminal_node(list(x.iloc[:, -1])) 
                           if len(x.iloc[:, -1]) <= min_size 
                           else grow_tree(x, select_node(get_split_costs(x)),
                                        depth + 1, max_depth, min_size))(right)
               }

# %%
def bootstrap(df, random_state):
    return df.sample(len(df), replace = True, random_state = random_state)

# %%
def grow_random_forest(df, max_depth = 1, min_size = 5, no_of_trees = 10):  
    return [grow_tree(
        bootstrap(df, i), select_node( get_split_costs(bootstrap(df, i))),
        1, max_depth, min_size) for i in range(0, no_of_trees)]

# %%
def tree_predict_row(row, tree):
    
    '''use the trained tree to partition the feature space of the test observation and return 
    the partition prediction value, which for regression is the mean of the partition'''
    
    if row[tree['node']['feature']] <  tree['node']['split']:
        if not isinstance(tree['left'], dict):
            return tree['left']
        else:
            return tree_predict_row(row, tree['left'])
    else:
         if not isinstance(tree['right'], dict):
            return tree['right']
         else:
            return tree_predict_row(row, tree['right'],)

# %%
def forest_predict_row(row, forest):
    
    ''' predicts each row of df for each tree than takes the average across 
    all trees for each row '''
    
    return np.mean([tree_predict_row(row, tree) for tree in forest])

# %%
def predict(df, forest):

    ''' applies predict row function to a df of test observations '''
    
    return df.apply(forest_predict_row, axis = 1, forest = forest)

# %%
def mse(y, predicted_y):
    
    ''' returns the mean square error: the sum of squyared differences between predicted y and actual y'''
    
    return np.sum((y - predicted_y)**2)

# %%
def total_sum_of_squares(y):

    '''returns the total sum of squares: the sum of squared difference between y and the mean of y i.e var(y)'''
    
    return np.sum((y - np.mean(y))**2)

# %%
def r_squared(y, predicted_y):
   
    ''' retruns to proportion of variance attributable the model: 1 - the ratio of mse to total sum of squares.'''

    return 1 - (mse(y, predicted_y)/total_sum_of_squares(y))

# %%
toy_forest = grow_random_forest(toy_data, 1, 5, 100)

# %%
display(toy_forest)
# Out:
# [{'node': {'feature': 'c', 'split': 7, 'cost': 4379.6},
#   'left': 69.2,
#   'right': 35.8},
#  {'node': {'feature': 'a', 'split': 9, 'cost': 1856.875},
#   'left': 9.0,
#   'right': 49.125},
#  {'node': {'feature': 'c', 'split': 4, 'cost': 2884.222222222222},
#   'left': 69.0,
#   'right': 36.55555555555556},
#  {'node': {'feature': 'c', 'split': 8, 'cost': 1323.5555555555557},
#   'left': 59.22222222222222,
#   'right': 9.0},
#  {'node': {'feature': 'c', 'split': 4, 'cost': 1848.8333333333335},
#   'left': 69.0,
#   'right': 38.166666666666664},
#  {'node': {'feature': 'c', 'split': 10, 'cost': 1265.875},
#   'left': 58.375,
#   'right': 20.0},
#  {'node': {'feature': 'c', 'split': 6, 'cost': 217.58333333333331},
#   'left': 39.25,
#   'right': 68.83333333333333},
#  {'node': {'feature': 'c', 'split': 10, 'cost': 652.2222222222223},
#   'left': 67.55555555555556,
#   'right': 20.0},
#  {'node': {'feature': 'c', 'split': 8, 'cost': 4213.714285714285},
#   'left': 56.42857142857143,
#   'right': 30.0},
#  {'node': {'feature': 'c', 'split': 10, 'cost': 2113.4285714285716},
#   'left': 42.285714285714285,
#   'right': 20.0},
#  {'node': {'feature': 'a', 'split': 44, 'cost': 434.0},
#   'left': 62.2,
#   'right': 42.4},
#  {'node': {'feature': 'c', 'split': 2, 'cost': 878.0},
#   'left': 69.0,
#   'right': 43.5},
#  {'node': {'feature': 'c', 'split': 7, 'cost': 4123.6},
#   'left': 54.8,
#   'right': 29.2},
#  {'node': {'feature': 'a', 'split': 39, 'cost': 765.5833333333334},
#   'left': 71.25,
#   'right': 31.166666666666668},
#  {'node': {'feature': 'c', 'split': 10, 'cost': 700.0},
#   'left': 58.0,
#   'right': 20.0},
#  {'node': {'feature': 'c', 'split': 8, 'cost': 1139.5833333333335},
#   'left': 56.166666666666664,
#   'right': 11.75},
#  {'node': {'feature': 'a', 'split': 44, 'cost': 3048.0},
#   'left': 56.0,
#   'right': 43.0},
#  {'node': {'feature': 'a', 'split': 39, 'cost': 638.0},
#   'left': 69.2,
#   'right': 28.6},
#  {'node': {'feature': 'c', 'split': 7, 'cost': 1275.3333333333333},
#   'left': 48.666666666666664,
#   'right': 21.0},
#  {'node': {'feature': 'c', 'split': 7, 'cost': 3331.7142857142853},
#   'left': 57.0,
#   'right': 26.428571428571427},
#  {'node': {'feature': 'c', 'split': 10, 'cost': 4090.875},
#   'left': 51.125,
#   'right': 20.0},
#  {'node': {'feature': 'a', 'split': 19, 'cost': 851.375},
#   'left': 74.5,
#   'right': 44.875},
#  {'node': {'feature': 'a', 'split': 39, 'cost': 3764.0833333333326},
#   'left': 57.333333333333336,
#   'right': 27.75},
#  {'node': {'feature': 'a', 'split': 39, 'cost': 939.7142857142857},
#   'left': 63.57142857142857,
#   'right': 20.0},
#  {'node': {'feature': 'c', 'split': 6, 'cost': 2754.0},
#   'left': 45.2,
#   'right': 64.6},
#  {'node': {'feature': 'a', 'split': 39, 'cost': 3419.5238095238096},
#   'left': 57.857142857142854,
#   'right': 27.333333333333332},
#  {'node': {'feature': 'a', 'split': 3, 'cost': 2844.0},
#   'left': 77.0,
#   'right': 34.666666666666664},
#  {'node': {'feature': 'a', 'split': 3, 'cost': 1994.0},
#   'left': 77.0,
#   'right': 41.0},
#  {'node': {'feature': 'a', 'split': 3, 'cost': 3651.875},
#   'left': 77.0,
#   'right': 45.375},
#  {'node': {'feature': 'c', 'split': 8, 'cost': 2432.0},
#   'left': 52.5,
#   'right': 9.0},
#  {'node': {'feature': 'a', 'split': 3, 'cost': 6398.0},
#   'left': 77.0,
#   'right': 40.333333333333336},
#  {'node': {'feature': 'c', 'split': 2, 'cost': 1699.5},
#   'left': 69.0,
#   'right': 31.25},
#  {'node': {'feature': 'c', 'split': 8, 'cost': 706.095238095238},
#   'left': 66.71428571428571,
#   'right': 12.666666666666666},
#  {'node': {'feature': 'a', 'split': 39, 'cost': 663.5238095238094},
#   'left': 67.14285714285714,
#   'right': 23.333333333333332},
#  {'node': {'feature': 'a', 'split': 3, 'cost': 4762.222222222223},
#   'left': 77.0,
#   'right': 38.55555555555556},
#  {'node': {'feature': 'a', 'split': 44, 'cost': 747.375},
#   'left': 58.875,
#   'right': 41.5},
#  {'node': {'feature': 'a', 'split': 9, 'cost': 4670.0},
#   'left': 30.0,
#   'right': 44.0},
#  {'node': {'feature': 'c', 'split': 8, 'cost': 1254.0833333333333},
#   'left': 60.666666666666664,
#   'right': 11.75},
#  {'node': {'feature': 'a', 'split': 44, 'cost': 3338.0},
#   'left': 58.2,
#   'right': 36.4},
#  {'node': {'feature': 'a', 'split': 39, 'cost': 1016.0952380952381},
#   'left': 65.71428571428571,
#   'right': 37.333333333333336},
#  {'node': {'feature': 'c', 'split': 7, 'cost': 1456.0833333333333},
#   'left': 57.666666666666664,
#   'right': 19.75},
#  {'node': {'feature': 'c', 'split': 8, 'cost': 2689.5555555555557},
#   'left': 54.22222222222222,
#   'right': 9.0},
#  {'node': {'feature': 'c', 'split': 10, 'cost': 1868.0},
#   'left': 64.0,
#   'right': 20.0},
#  {'node': {'feature': 'c', 'split': 2, 'cost': 3568.888888888889},
#   'left': 69.0,
#   'right': 43.888888888888886},
#  {'node': {'feature': 'a', 'split': 19, 'cost': 142.09523809523807},
#   'left': 73.28571428571429,
#   'right': 43.333333333333336},
#  {'node': {'feature': 'c', 'split': 8, 'cost': 4140.857142857143},
#   'left': 58.857142857142854,
#   'right': 30.0},
#  {'node': {'feature': 'a', 'split': 53, 'cost': 3283.875},
#   'left': 51.625,
#   'right': 25.0},
#  {'node': {'feature': 'c', 'split': 10, 'cost': 1342.8888888888891},
#   'left': 59.888888888888886,
#   'right': 20.0},
#  {'node': {'feature': 'c', 'split': 10, 'cost': 2067.875},
#   'left': 49.375,
#   'right': 20.0},
#  {'node': {'feature': 'a', 'split': 39, 'cost': 5056.083333333334},
#   'left': 36.333333333333336,
#   'right': 26.75},
#  {'node': {'feature': 'c', 'split': 7, 'cost': 2850.0},
#   'left': 43.0,
#   'right': 25.0},
#  {'node': {'feature': 'c', 'split': 8, 'cost': 3564.0000000000005},
#   'left': 56.8,
#   'right': 21.6},
#  {'node': {'feature': 'a', 'split': 3, 'cost': 3986.0},
#   'left': 77.0,
#   'right': 37.0},
#  {'node': {'feature': 'a', 'split': 19, 'cost': 4726.083333333333},
#   'left': 24.75,
#   'right': 44.333333333333336},
#  {'node': {'feature': 'a', 'split': 9, 'cost': 2662.0},
#   'left': 9.0,
#   'right': 46.0},
#  {'node': {'feature': 'a', 'split': 3, 'cost': 4141.555555555556},
#   'left': 77.0,
#   'right': 39.22222222222222},
#  {'node': {'feature': 'c', 'split': 10, 'cost': 4226.222222222223},
#   'left': 54.44444444444444,
#   'right': 20.0},
#  {'node': {'feature': 'c', 'split': 8, 'cost': 1430.6666666666667},
#   'left': 48.0,
#   'right': 16.333333333333332},
#  {'node': {'feature': 'c', 'split': 8, 'cost': 4034.0},
#   'left': 62.0,
#   'right': 30.0},
#  {'node': {'feature': 'a', 'split': 3, 'cost': 2994.0},
#   'left': 77.0,
#   'right': 50.5},
#  {'node': {'feature': 'c', 'split': 10, 'cost': 2424.8888888888887},
#   'left': 48.888888888888886,
#   'right': 20.0},
#  {'node': {'feature': 'c', 'split': 7, 'cost': 1619.5},
#   'left': 62.5,
#   'right': 21.0},
#  {'node': {'feature': 'c', 'split': 8, 'cost': 4615.428571428572},
#   'left': 46.285714285714285,
#   'right': 30.0},
#  {'node': {'feature': 'a', 'split': 39, 'cost': 3723.5833333333335},
#   'left': 56.75,
#   'right': 33.166666666666664},
#  {'node': {'feature': 'a', 'split': 39, 'cost': 3854.0},
#   'left': 59.8,
#   'right': 28.6},
#  {'node': {'feature': 'c', 'split': 8, 'cost': 700.4000000000001},
#   'left': 49.4,
#   'right': 13.4},
#  {'node': {'feature': 'a', 'split': 39, 'cost': 4021.5833333333335},
#   'left': 62.166666666666664,
#   'right': 34.25},
#  {'node': {'feature': 'c', 'split': 8, 'cost': 336.0952380952381},
#   'left': 70.28571428571429,
#   'right': 12.666666666666666},
#  {'node': {'feature': 'c', 'split': 10, 'cost': 2596.2222222222217},
#   'left': 61.55555555555556,
#   'right': 20.0},
#  {'node': {'feature': 'a', 'split': 39, 'cost': 721.6},
#   'left': 63.2,
#   'right': 26.8},
#  {'node': {'feature': 'c', 'split': 7, 'cost': 5308.857142857141},
#   'left': 54.0,
#   'right': 30.857142857142858},
#  {'node': {'feature': 'c', 'split': 10, 'cost': 2282.8888888888887},
#   'left': 49.888888888888886,
#   'right': 20.0},
#  {'node': {'feature': 'a', 'split': 9, 'cost': 4096.0},
#   'left': 22.6,
#   'right': 51.2},
#  {'node': {'feature': 'c', 'split': 10, 'cost': 2549.5},
#   'left': 51.25,
#   'right': 20.0},
#  {'node': {'feature': 'a', 'split': 3, 'cost': 4632.875},
#   'left': 77.0,
#   'right': 49.125},
#  {'node': {'feature': 'c', 'split': 7, 'cost': 1109.375},
#   'left': 47.875,
#   'right': 22.5},
#  {'node': {'feature': 'a', 'split': 19, 'cost': 565.4285714285714},
#   'left': 69.0,
#   'right': 37.714285714285715},
#  {'node': {'feature': 'c', 'split': 8, 'cost': 4777.0},
#   'left': 62.0,
#   'right': 40.5},
#  {'node': {'feature': 'a', 'split': 39, 'cost': 3546.875},
#   'left': 57.125,
#   'right': 20.0},
#  {'node': {'feature': 'a', 'split': 19, 'cost': 380.0},
#   'left': 71.2,
#   'right': 38.6},
#  {'node': {'feature': 'a', 'split': 3, 'cost': 3539.714285714286},
#   'left': 77.0,
#   'right': 35.57142857142857},
#  {'node': {'feature': 'a', 'split': 19, 'cost': 619.5833333333334},
#   'left': 75.75,
#   'right': 43.166666666666664},
#  {'node': {'feature': 'a', 'split': 39, 'cost': 487.33333333333337},
#   'left': 77.0,
#   'right': 31.666666666666668},
#  {'node': {'feature': 'a', 'split': 19, 'cost': 432.75},
#   'left': 71.75,
#   'right': 43.0},
#  {'node': {'feature': 'a', 'split': 19, 'cost': 3523.714285714286},
#   'left': 30.0,
#   'right': 47.42857142857143},
#  {'node': {'feature': 'c', 'split': 6, 'cost': 4452.380952380952},
#   'left': 50.666666666666664,
#   'right': 61.57142857142857},
#  {'node': {'feature': 'a', 'split': 19, 'cost': 772.0952380952381},
#   'left': 72.66666666666667,
#   'right': 52.714285714285715},
#  {'node': {'feature': 'c', 'split': 10, 'cost': 1416.0},
#   'left': 62.0,
#   'right': 20.0},
#  {'node': {'feature': 'c', 'split': 7, 'cost': 2779.5833333333335},
#   'left': 43.166666666666664,
#   'right': 28.75},
#  {'node': {'feature': 'a', 'split': 3, 'cost': 3578.0000000000005},
#   'left': 77.0,
#   'right': 41.333333333333336},
#  {'node': {'feature': 'a', 'split': 3, 'cost': 3571.875},
#   'left': 77.0,
#   'right': 39.625},
#  {'node': {'feature': 'c', 'split': 8, 'cost': 4388.333333333333},
#   'left': 32.666666666666664,
#   'right': 40.5},
#  {'node': {'feature': 'a', 'split': 39, 'cost': 739.8333333333333},
#   'left': 70.5,
#   'right': 33.166666666666664},
#  {'node': {'feature': 'c', 'split': 6, 'cost': 5728.0},
#   'left': 41.5,
#   'right': 52.75},
#  {'node': {'feature': 'a', 'split': 3, 'cost': 2360.0},
#   'left': 77.0,
#   'right': 32.0},
#  {'node': {'feature': 'a', 'split': 39, 'cost': 3308.0},
#   'left': 58.2,
#   'right': 25.4},
#  {'node': {'feature': 'a', 'split': 39, 'cost': 394.0952380952382},
#   'left': 69.33333333333333,
#   'right': 26.285714285714285},
#  {'node': {'feature': 'c', 'split': 7, 'cost': 4334.0},
#   'left': 69.4,
#   'right': 35.8},
#  {'node': {'feature': 'c', 'split': 10, 'cost': 3255.5555555555557},
#   'left': 55.22222222222222,
#   'right': 20.0},
#  {'node': {'feature': 'a', 'split': 47, 'cost': 3522.0},
#   'left': 56.5,
#   'right': 31.0}]

# %%
predict(toy_data_test, toy_forest)
# Out:
# 0    38.810437
# 1    51.466849
# 2    45.851623
# 3    40.487806
# 4    31.760687
# 5    39.290556
# 6    31.760687
# 7    31.760687
# 8    40.487806
# 9    44.057480
# dtype: float64

# %%
boston_forest = grow_random_forest(train,max_depth = 5, min_size = 5, no_of_trees = 100)

# %%
display(boston_forest)
# Out:
# [{'node': {'feature': 'RM', 'split': 6.678, 'cost': 18117.63403073744},
#   'left': {'node': {'feature': 'DIS',
#     'split': 1.1742,
#     'cost': 6796.653598484849},
#    'left': 50.0,
#    'right': {'node': {'feature': 'INDUS',
#      'split': 18.1,
#      'cost': 4117.947542293234},
#     'left': {'node': {'feature': 'NOX',
#       'split': 0.515,
#       'cost': 1532.706918767507},
#      'left': {'node': {'feature': 'DIS',
#        'split': 6.32,
#        'cost': 608.5017304075233},
#       'left': 23.270909090909093,
#       'right': 20.76206896551724},
#      'right': {'node': {'feature': 'DIS',
#        'split': 4.4986,
#        'cost': 756.25568627451},
#       'left': 18.880392156862744,
#       'right': 20.829411764705885}},
#     'right': {'node': {'feature': 'LSTAT',
#       'split': 15.17,
#       'cost': 1215.7224923747276},
#      'left': {'node': {'feature': 'LSTAT',
#        'split': 14.43,
#        'cost': 81.34666666666666},
#       'left': 21.288888888888888,
#       'right': 17.311111111111114},
#      'right': {'node': {'feature': 'LSTAT',
#        'split': 20.31,
#        'cost': 748.1980392156862},
#       'left': 15.164705882352942,
#       'right': 11.386274509803922}}}},
#   'right': {'node': {'feature': 'NOX',
#     'split': 0.671,
#     'cost': 6102.162927215189},
#    'left': {'node': {'feature': 'B',
#      'split': 389.85,
#      'cost': 4338.7081349782275},
#     'left': {'node': {'feature': 'CHAS',
#       'split': 1.0,
#       'cost': 1400.6633986928102},
#      'left': {'node': {'feature': 'AGE',
#        'split': 100.0,
#        'cost': 981.6599999999997},
#       'left': 40.3,
#       'right': 27.5},
#      'right': {'node': {'feature': 'TAX', 'split': 403.0, 'cost': 0.0},
#       'left': 46.0,
#       'right': 50.0}},
#     'right': {'node': {'feature': 'NOX',
#       'split': 0.484,
#       'cost': 1785.162432432432},
#      'left': {'node': {'feature': 'RAD',
#        'split': 2.0,
#        'cost': 945.7451874999997},
#       'left': 27.82,
#       'right': 35.140625},
#      'right': {'node': {'feature': 'CRIM',
#        'split': 6.53876,
#        'cost': 108.85333333333331},
#       'left': 26.933333333333334,
#       'right': 50.0}}},
#    'right': {'node': {'feature': 'NOX',
#      'split': 0.718,
#      'cost': 28.507500000000004},
#     'left': 14.125,
#     'right': 21.9}}},
#  {'node': {'feature': 'PTRATIO', 'split': 18.2, 'cost': 20645.606675110394},
#   'left': {'node': {'feature': 'TAX',
#     'split': 233.0,
#     'cost': 9890.766349206348},
#    'left': 46.5,
#    'right': {'node': {'feature': 'B',
#      'split': 353.89,
#      'cost': 8925.285357142855},
#     'left': {'node': {'feature': 'RM',
#       'split': 6.101,
#       'cost': 42.24755555555552},
#      'left': {'node': {'feature': 'DIS',
#        'split': 1.6232,
#        'cost': 4.419999999999992},
#       'left': 15.333333333333334,
#       'right': 19.366666666666664},
#      'right': 23.439999999999998},
#     'right': {'node': {'feature': 'RM', 'split': 6.782, 'cost': 3171.4465},
#      'left': {'node': {'feature': 'CRIM',
#        'split': 0.14476,
#        'cost': 830.723125},
#       'left': 23.310416666666665,
#       'right': 20.241666666666667},
#      'right': {'node': {'feature': 'ZN',
#        'split': 20.0,
#        'cost': 1741.9751098901097},
#       'left': 41.62857142857143,
#       'right': 34.61153846153846}}}},
#   'right': {'node': {'feature': 'AGE',
#     'split': 91.7,
#     'cost': 6716.55005577428},
#    'left': {'node': {'feature': 'DIS', 'split': 1.5004, 'cost': 2290.312},
#     'left': 50.0,
#     'right': {'node': {'feature': 'B',
#       'split': 341.6,
#       'cost': 1703.5230383480825},
#      'left': {'node': {'feature': 'LSTAT',
#        'split': 17.16,
#        'cost': 111.60514285714284},
#       'left': 18.42,
#       'right': 11.157142857142857},
#      'right': {'node': {'feature': 'RM',
#        'split': 6.398,
#        'cost': 896.261584541063},
#       'left': 20.43111111111111,
#       'right': 25.8695652173913}}},
#    'right': {'node': {'feature': 'NOX',
#      'split': 0.668,
#      'cost': 2126.082027204914},
#     'left': {'node': {'feature': 'PTRATIO',
#       'split': 21.0,
#       'cost': 1510.5452608695655},
#      'left': {'node': {'feature': 'INDUS',
#        'split': 27.74,
#        'cost': 1291.291724137931},
#       'left': 19.055172413793105,
#       'right': 8.1},
#      'right': {'node': {'feature': 'B',
#        'split': 387.94,
#        'cost': 60.88651785714287},
#       'left': 13.457142857142856,
#       'right': 16.40625}},
#     'right': {'node': {'feature': 'NOX',
#       'split': 0.7,
#       'cost': 324.3419264069264},
#      'left': {'node': {'feature': 'B', 'split': 376.11, 'cost': 169.8075},
#       'left': 8.025,
#       'right': 10.8},
#      'right': {'node': {'feature': 'DIS',
#        'split': 2.0651,
#        'cost': 82.4178181818182},
#       'left': 12.58,
#       'right': 15.57272727272727}}}}},
#  {'node': {'feature': 'PTRATIO', 'split': 19.2, 'cost': 26312.43591364145},
#   'left': {'node': {'feature': 'B',
#     'split': 394.51,
#     'cost': 15049.964193939395},
#    'left': {'node': {'feature': 'TAX',
#      'split': 265.0,
#      'cost': 9582.35832752613},
#     'left': {'node': {'feature': 'NOX',
#       'split': 0.447,
#       'cost': 2324.0170000000003},
#      'left': {'node': {'feature': 'DIS',
#        'split': 9.2229,
#        'cost': 46.85714285714286},
#       'left': 47.142857142857146,
#       'right': 33.0},
#      'right': {'node': {'feature': 'TAX',
#        'split': 264.0,
#        'cost': 887.6619047619049},
#       'left': 28.628571428571426,
#       'right': 45.633333333333326}},
#     'right': {'node': {'feature': 'RAD',
#       'split': 8.0,
#       'cost': 5448.6047058823515},
#      'left': {'node': {'feature': 'RM',
#        'split': 6.943,
#        'cost': 1311.9703216783216},
#       'left': 22.71272727272727,
#       'right': 39.69230769230769},
#      'right': {'node': {'feature': 'RM',
#        'split': 8.247,
#        'cost': 76.56888888888888},
#       'left': 29.011111111111113,
#       'right': 46.9}}},
#    'right': {'node': {'feature': 'LSTAT',
#      'split': 5.9,
#      'cost': 1504.201403508772},
#     'left': {'node': {'feature': 'RM',
#       'split': 7.923,
#       'cost': 273.17964285714277},
#      'left': {'node': {'feature': 'RM',
#        'split': 7.024,
#        'cost': 101.48749999999998},
#       'left': 29.4,
#       'right': 35.474999999999994},
#      'right': 43.575},
#     'right': {'node': {'feature': 'PTRATIO',
#       'split': 15.2,
#       'cost': 449.69686274509814},
#      'left': {'node': {'feature': 'CRIM', 'split': 4.0974, 'cost': 0.0},
#       'left': 13.4,
#       'right': 15.6},
#      'right': {'node': {'feature': 'RM',
#        'split': 6.273,
#        'cost': 249.93969354838714},
#       'left': 20.777419354838706,
#       'right': 24.765000000000004}}}},
#   'right': {'node': {'feature': 'CRIM',
#     'split': 9.33889,
#     'cost': 8274.220544217687},
#    'left': {'node': {'feature': 'DIS',
#      'split': 1.4394,
#      'cost': 2086.561739130435},
#     'left': 50.0,
#     'right': {'node': {'feature': 'DIS',
#       'split': 2.1069,
#       'cost': 1651.824549019608},
#      'left': {'node': {'feature': 'LSTAT',
#        'split': 14.64,
#        'cost': 151.72160000000002},
#       'left': 24.139999999999997,
#       'right': 13.595999999999998},
#      'right': {'node': {'feature': 'LSTAT',
#        'split': 14.65,
#        'cost': 516.7308045977012},
#       'left': 21.46896551724138,
#       'right': 16.15555555555556}}},
#    'right': {'node': {'feature': 'CRIM',
#      'split': 15.0234,
#      'cost': 1266.464377104377},
#     'left': {'node': {'feature': 'LSTAT',
#       'split': 16.35,
#       'cost': 507.0791428571428},
#      'left': {'node': {'feature': 'RM',
#        'split': 5.648,
#        'cost': 16.20749999999998},
#       'left': 24.7,
#       'right': 20.775},
#      'right': {'node': {'feature': 'B',
#        'split': 379.7,
#        'cost': 444.1385858585858},
#       'left': 11.318181818181818,
#       'right': 13.344444444444445}},
#     'right': {'node': {'feature': 'DIS',
#       'split': 1.4165,
#       'cost': 121.26917647058825},
#      'left': 14.62,
#      'right': 9.641176470588235}}}},
#  {'node': {'feature': 'RM', 'split': 7.691, 'cost': 20661.354851994853},
#   'left': {'node': {'feature': 'CRIM',
#     'split': 9.33889,
#     'cost': 16077.162912674516},
#    'left': {'node': {'feature': 'CRIM',
#      'split': 9.2323,
#      'cost': 12217.973669064748},
#     'left': {'node': {'feature': 'RM',
#       'split': 6.604,
#       'cost': 8527.123339203354},
#      'left': {'node': {'feature': 'DIS',
#        'split': 1.4118,
#        'cost': 3089.361900452488},
#       'left': 50.0,
#       'right': 19.667873303167422},
#      'right': {'node': {'feature': 'DIS', 'split': 2.0788, 'cost': 1134.28},
#       'left': 44.199999999999996,
#       'right': 28.600000000000005}},
#     'right': 50.0},
#    'right': 12.576923076923077},
#   'right': {'node': {'feature': 'B',
#     'split': 390.77,
#     'cost': 285.1099999999999},
#    'left': {'node': {'feature': 'B',
#      'split': 388.45,
#      'cost': 138.05999999999997},
#     'left': {'node': {'feature': 'AGE',
#       'split': 86.5,
#       'cost': 115.17866666666666},
#      'left': 48.96,
#      'right': 45.46666666666667},
#     'right': {'node': {'feature': 'TAX', 'split': 403.0, 'cost': 0.0},
#      'left': 50.0,
#      'right': 50.0}},
#    'right': 42.1}},
#  {'node': {'feature': 'LSTAT', 'split': 9.74, 'cost': 16187.699212865848},
#   'left': {'node': {'feature': 'RM',
#     'split': 7.454,
#     'cost': 6848.8082940309505},
#    'left': {'node': {'feature': 'CRIM',
#      'split': 6.53876,
#      'cost': 3257.1899122807013},
#     'left': {'node': {'feature': 'PTRATIO',
#       'split': 15.3,
#       'cost': 2619.864002425712},
#      'left': {'node': {'feature': 'DIS',
#        'split': 1.8773,
#        'cost': 212.65433333333326},
#       'left': 25.65,
#       'right': 33.69333333333333},
#      'right': {'node': {'feature': 'AGE',
#        'split': 100.0,
#        'cost': 1716.3295833333332},
#       'left': 25.86041666666667,
#       'right': 50.0}},
#     'right': 50.0},
#    'right': {'node': {'feature': 'PTRATIO',
#      'split': 20.2,
#      'cost': 456.42952380952363},
#     'left': {'node': {'feature': 'RAD',
#       'split': 4.0,
#       'cost': 353.54514705882343},
#      'left': 41.975,
#      'right': {'node': {'feature': 'AGE',
#        'split': 31.9,
#        'cost': 175.93733333333336},
#       'left': 42.8,
#       'right': 48.25333333333333}},
#     'right': 21.9}},
#   'right': {'node': {'feature': 'CRIM',
#     'split': 4.66883,
#     'cost': 2484.9832447397566},
#    'left': {'node': {'feature': 'DIS',
#      'split': 1.618,
#      'cost': 855.4219411764708},
#     'left': {'node': {'feature': 'RAD',
#       'split': 5.0,
#       'cost': 5.928333333333332},
#      'left': 14.1,
#      'right': {'node': {'feature': 'CRIM',
#        'split': 4.0974,
#        'cost': 3.8075000000000006},
#       'left': 14.375,
#       'right': 15.6}},
#     'right': {'node': {'feature': 'RM',
#       'split': 7.327,
#       'cost': 721.4709322033899},
#      'left': {'node': {'feature': 'RM',
#        'split': 6.101,
#        'cost': 679.2694586894587},
#       'left': 19.36153846153846,
#       'right': 20.785185185185192},
#      'right': 31.0}},
#    'right': {'node': {'feature': 'RM',
#      'split': 6.485,
#      'cost': 1158.4715789473685},
#     'left': {'node': {'feature': 'NOX',
#       'split': 0.668,
#       'cost': 622.3167366946778},
#      'left': {'node': {'feature': 'RM',
#        'split': 5.617,
#        'cost': 86.81688888888888},
#       'left': 12.719999999999999,
#       'right': 17.811111111111114},
#      'right': {'node': {'feature': 'CRIM',
#        'split': 9.18702,
#        'cost': 267.4337664473684},
#       'left': 14.521052631578948,
#       'right': 10.584375}},
#     'right': {'node': {'feature': 'DIS',
#       'split': 1.4655,
#       'cost': 296.25683333333336},
#      'left': 13.025,
#      'right': {'node': {'feature': 'B',
#        'split': 179.36,
#        'cost': 179.35428571428568},
#       'left': 15.200000000000001,
#       'right': 20.571428571428573}}}}},
#  {'node': {'feature': 'CRIM', 'split': 6.71772, 'cost': 25489.939499263623},
#   'left': {'node': {'feature': 'LSTAT',
#     'split': 5.49,
#     'cost': 9174.151210556513},
#    'left': {'node': {'feature': 'CRIM',
#      'split': 0.52693,
#      'cost': 1107.8144827586207},
#     'left': {'node': {'feature': 'RM',
#       'split': 7.645,
#       'cost': 348.57714285714286},
#      'left': {'node': {'feature': 'NOX',
#        'split': 0.538,
#        'cost': 182.50952380952384},
#       'left': 32.904761904761905,
#       'right': 24.0},
#      'right': {'node': {'feature': 'TAX',
#        'split': 307.0,
#        'cost': 30.026666666666635},
#       'left': 47.0,
#       'right': 41.06666666666666}},
#     'right': 50.0},
#    'right': {'node': {'feature': 'PTRATIO',
#      'split': 14.7,
#      'cost': 4699.381016260162},
#     'left': 43.43333333333334,
#     'right': {'node': {'feature': 'RM',
#       'split': 6.481,
#       'cost': 2918.8844283559583},
#      'left': {'node': {'feature': 'B',
#        'split': 330.04,
#        'cost': 1868.5946311475411},
#       'left': 16.224999999999998,
#       'right': 20.29344262295082},
#      'right': {'node': {'feature': 'LSTAT',
#        'split': 7.73,
#        'cost': 627.1012695924767},
#       'left': 28.055172413793105,
#       'right': 23.704545454545453}}}},
#   'right': {'node': {'feature': 'AGE',
#     'split': 83.7,
#     'cost': 4075.283157894737},
#    'left': {'node': {'feature': 'CRIM',
#      'split': 9.91655,
#      'cost': 18.552500000000002},
#     'left': 11.35,
#     'right': 8.425},
#    'right': {'node': {'feature': 'CRIM',
#      'split': 15.0234,
#      'cost': 3412.590523809524},
#     'left': {'node': {'feature': 'B',
#       'split': 376.11,
#       'cost': 2863.7583066361553},
#      'left': {'node': {'feature': 'LSTAT',
#        'split': 12.13,
#        'cost': 615.5257142857141},
#       'left': 50.0,
#       'right': 16.685714285714283},
#      'right': {'node': {'feature': 'AGE',
#        'split': 93.9,
#        'cost': 114.65529411764706},
#       'left': 20.7,
#       'right': 12.97058823529412}},
#     'right': {'node': {'feature': 'NOX',
#       'split': 0.679,
#       'cost': 59.13333333333334},
#      'left': {'node': {'feature': 'DIS', 'split': 1.5894, 'cost': 16.2725},
#       'left': 12.625,
#       'right': 14.15},
#      'right': {'node': {'feature': 'CRIM',
#        'split': 38.3518,
#        'cost': 12.379999999999999},
#       'left': 9.366666666666667,
#       'right': 5.666666666666667}}}}},
#  {'node': {'feature': 'INDUS', 'split': 4.05, 'cost': 24759.06211221122},
#   'left': {'node': {'feature': 'RM',
#     'split': 7.454,
#     'cost': 1032.2508704453442},
#    'left': {'node': {'feature': 'RM',
#      'split': 6.728,
#      'cost': 448.8030769230768},
#     'left': {'node': {'feature': 'TAX',
#       'split': 280.0,
#       'cost': 33.403055555555554},
#      'left': 29.424999999999997,
#      'right': {'node': {'feature': 'PTRATIO',
#        'split': 22.0,
#        'cost': 8.600000000000001},
#       'left': 23.4,
#       'right': 20.6}},
#     'right': {'node': {'feature': 'LSTAT',
#       'split': 5.5,
#       'cost': 161.93749999999997},
#      'left': {'node': {'feature': 'B',
#        'split': 390.49,
#        'cost': 56.03858585858583},
#       'left': 31.855555555555554,
#       'right': 34.78181818181818},
#      'right': 27.74}},
#    'right': {'node': {'feature': 'PTRATIO',
#      'split': 14.9,
#      'cost': 41.96299999999999},
#     'left': 48.62,
#     'right': {'node': {'feature': 'CHAS',
#       'split': 1.0,
#       'cost': 0.06857142857143053},
#      'left': {'node': {'feature': 'RAD',
#        'split': 3.0,
#        'cost': 1.5146129380243427e-28},
#       'left': 43.79999999999999,
#       'right': 44.0},
#      'right': 46.0}}},
#   'right': {'node': {'feature': 'PTRATIO',
#     'split': 17.8,
#     'cost': 16593.84986107252},
#    'left': {'node': {'feature': 'LSTAT',
#      'split': 6.29,
#      'cost': 1282.4979651162791},
#     'left': {'node': {'feature': 'DIS',
#       'split': 3.2157,
#       'cost': 186.78181818181827},
#      'left': {'node': {'feature': 'INDUS',
#        'split': 19.58,
#        'cost': 141.91875000000007},
#       'left': 50.0,
#       'right': 46.7375},
#      'right': 33.5},
#     'right': {'node': {'feature': 'INDUS',
#       'split': 19.58,
#       'cost': 351.8016060606061},
#      'left': {'node': {'feature': 'CRIM',
#        'split': 0.44791,
#        'cost': 159.7936666666667},
#       'left': 23.323333333333338,
#       'right': 27.2},
#      'right': {'node': {'feature': 'CHAS', 'split': 1.0, 'cost': 93.9},
#       'left': 22.125,
#       'right': 16.15}}},
#    'right': {'node': {'feature': 'CRIM',
#      'split': 9.33889,
#      'cost': 8881.841619807936},
#     'left': {'node': {'feature': 'AGE',
#       'split': 36.6,
#       'cost': 6814.680262180017},
#      'left': {'node': {'feature': 'CRIM',
#        'split': 0.05789,
#        'cost': 63.69626666666668},
#       'left': 27.933333333333334,
#       'right': 23.396000000000004},
#      'right': {'node': {'feature': 'LSTAT',
#        'split': 5.29,
#        'cost': 3803.5005294117645},
#       'left': 50.0,
#       'right': 18.677058823529414}},
#     'right': {'node': {'feature': 'NOX',
#       'split': 0.668,
#       'cost': 783.5202150537636},
#      'left': {'node': {'feature': 'B',
#        'split': 35.05,
#        'cost': 229.89999999999995},
#       'left': 10.2,
#       'right': 20.6},
#      'right': 10.361290322580643}}}},
#  {'node': {'feature': 'LSTAT', 'split': 9.04, 'cost': 17615.870114662604},
#   'left': {'node': {'feature': 'LSTAT',
#     'split': 4.7,
#     'cost': 7730.680675883255},
#    'left': {'node': {'feature': 'RM',
#      'split': 7.454,
#      'cost': 974.3571428571427},
#     'left': {'node': {'feature': 'CRIM',
#       'split': 1.22358,
#       'cost': 159.18400000000003},
#      'left': {'node': {'feature': 'NOX',
#        'split': 0.404,
#        'cost': 37.70928571428569},
#       'left': 29.1,
#       'right': 33.79285714285714},
#      'right': {'node': {'feature': 'RAD', 'split': 24.0, 'cost': 0.0},
#       'left': 41.3,
#       'right': 50.0}},
#     'right': {'node': {'feature': 'PTRATIO',
#       'split': 15.9,
#       'cost': 86.88909090909081},
#      'left': {'node': {'feature': 'LSTAT', 'split': 3.16, 'cost': 0.0},
#       'left': 50.0,
#       'right': 50.0},
#      'right': {'node': {'feature': 'AGE',
#        'split': 86.5,
#        'cost': 51.26399999999993},
#       'left': 43.86,
#       'right': 37.6}}},
#    'right': {'node': {'feature': 'B',
#      'split': 354.31,
#      'cost': 4976.279540229885},
#     'left': {'node': {'feature': 'LSTAT', 'split': 8.88, 'cost': 0.0},
#      'left': 27.0,
#      'right': 50.0},
#     'right': {'node': {'feature': 'DIS',
#       'split': 2.505,
#       'cost': 2861.206075949367},
#      'left': {'node': {'feature': 'ZN',
#        'split': 20.0,
#        'cost': 49.29866666666665},
#       'left': 24.433333333333334,
#       'right': 48.14},
#      'right': {'node': {'feature': 'TAX',
#        'split': 223.0,
#        'cost': 1389.9596825396827},
#       'left': 32.68571428571428,
#       'right': 25.08888888888889}}}},
#   'right': {'node': {'feature': 'LSTAT',
#     'split': 15.1,
#     'cost': 2660.9246760728},
#    'left': {'node': {'feature': 'TAX',
#      'split': 304.0,
#      'cost': 889.6174818216607},
#     'left': {'node': {'feature': 'NOX',
#       'split': 0.647,
#       'cost': 206.99189189189187},
#      'left': {'node': {'feature': 'AGE',
#        'split': 85.1,
#        'cost': 130.52931818181816},
#       'left': 21.245454545454546,
#       'right': 25.875},
#      'right': 30.7},
#     'right': {'node': {'feature': 'RAD',
#       'split': 5.0,
#       'cost': 490.22264705882355},
#      'left': {'node': {'feature': 'RAD',
#        'split': 4.0,
#        'cost': 52.02380952380955},
#       'left': 17.133333333333336,
#       'right': 19.385714285714283},
#      'right': {'node': {'feature': 'PTRATIO',
#        'split': 17.8,
#        'cost': 363.78466124661236},
#       'left': 23.144444444444442,
#       'right': 20.24878048780488}}},
#    'right': {'node': {'feature': 'CRIM',
#      'split': 0.75026,
#      'cost': 1144.1238936877073},
#     'left': {'node': {'feature': 'RM',
#       'split': 5.39,
#       'cost': 152.9097619047619},
#      'left': 8.1,
#      'right': {'node': {'feature': 'B',
#        'split': 395.24,
#        'cost': 101.26875294117647},
#       'left': 17.488,
#       'right': 19.74705882352941}},
#     'right': {'node': {'feature': 'LSTAT', 'split': 21.52, 'cost': 674.83475},
#      'left': {'node': {'feature': 'CRIM',
#        'split': 14.4383,
#        'cost': 256.0371052631579},
#       'left': 14.81842105263158,
#       'right': 21.9},
#      'right': {'node': {'feature': 'CRIM',
#        'split': 22.5971,
#        'cost': 197.43999999999997},
#       'left': 12.675000000000002,
#       'right': 7.55}}}}},
#  {'node': {'feature': 'INDUS', 'split': 6.91, 'cost': 23055.68050777008},
#   'left': {'node': {'feature': 'PTRATIO',
#     'split': 15.3,
#     'cost': 5547.061423809523},
#    'left': {'node': {'feature': 'INDUS',
#      'split': 1.32,
#      'cost': 535.8131818181818},
#     'left': 50.0,
#     'right': {'node': {'feature': 'CHAS',
#       'split': 1.0,
#       'cost': 390.952380952381},
#      'left': {'node': {'feature': 'AGE',
#        'split': 89.4,
#        'cost': 289.4316666666667},
#       'left': 32.78333333333333,
#       'right': 39.06666666666667},
#      'right': 46.0}},
#    'right': {'node': {'feature': 'INDUS',
#      'split': 6.2,
#      'cost': 3702.5910272168567},
#     'left': {'node': {'feature': 'B',
#       'split': 384.3,
#       'cost': 2087.6364016172506},
#      'left': {'node': {'feature': 'AGE',
#        'split': 52.3,
#        'cost': 39.868333333333354},
#       'left': 21.05,
#       'right': 17.483333333333334},
#      'right': {'node': {'feature': 'AGE',
#        'split': 17.5,
#        'cost': 1680.4379999999996},
#       'left': 33.980000000000004,
#       'right': 25.524999999999995}},
#     'right': {'node': {'feature': 'RAD',
#       'split': 8.0,
#       'cost': 1096.5367307692306},
#      'left': 32.925,
#      'right': {'node': {'feature': 'RM',
#        'split': 8.04,
#        'cost': 223.1422222222222},
#       'left': 26.044444444444444,
#       'right': 43.8}}}},
#   'right': {'node': {'feature': 'DIS',
#     'split': 1.3861,
#     'cost': 10964.919340717299},
#    'left': {'node': {'feature': 'RM',
#      'split': 7.313,
#      'cost': 418.63714285714286},
#     'left': {'node': {'feature': 'B', 'split': 347.88, 'cost': 0.0},
#      'left': 27.9,
#      'right': 50.0},
#     'right': 15.0},
#    'right': {'node': {'feature': 'TAX',
#      'split': 437.0,
#      'cost': 7231.5307145913575},
#     'left': {'node': {'feature': 'LSTAT',
#       'split': 5.64,
#       'cost': 1528.1812110091744},
#      'left': 43.879999999999995,
#      'right': {'node': {'feature': 'RM',
#        'split': 6.319,
#        'cost': 867.666747311828},
#       'left': 19.789247311827957,
#       'right': 25.0625}},
#     'right': {'node': {'feature': 'RM',
#       'split': 4.628,
#       'cost': 2742.0465833333337},
#      'left': 26.03333333333333,
#      'right': {'node': {'feature': 'CRIM',
#        'split': 5.87205,
#        'cost': 2109.0191301721534},
#       'left': 17.951162790697673,
#       'right': 13.21038961038961}}}}},
#  {'node': {'feature': 'INDUS', 'split': 6.91, 'cost': 22152.096180612207},
#   'left': {'node': {'feature': 'PTRATIO',
#     'split': 16.1,
#     'cost': 5555.667995833333},
#    'left': {'node': {'feature': 'LSTAT',
#      'split': 8.61,
#      'cost': 1035.7179999999996},
#     'left': {'node': {'feature': 'DIS',
#       'split': 3.7886,
#       'cost': 684.8933333333333},
#      'left': 47.9,
#      'right': {'node': {'feature': 'TAX',
#        'split': 296.0,
#        'cost': 237.79428571428565},
#       'left': 43.871428571428574,
#       'right': 33.3}},
#     'right': 30.52},
#    'right': {'node': {'feature': 'PTRATIO',
#      'split': 18.8,
#      'cost': 3415.8197320099257},
#     'left': {'node': {'feature': 'INDUS',
#       'split': 6.2,
#       'cost': 2196.924472049689},
#      'left': {'node': {'feature': 'RM',
#        'split': 7.024,
#        'cost': 416.2180555555556},
#       'left': 23.90277777777778,
#       'right': 35.18333333333334},
#      'right': {'node': {'feature': 'CRIM',
#        'split': 0.40771,
#        'cost': 650.1847499999999},
#       'left': 34.24,
#       'right': 24.6875}},
#     'right': {'node': {'feature': 'RM',
#       'split': 8.259,
#       'cost': 323.99866666666674},
#      'left': {'node': {'feature': 'LSTAT',
#        'split': 9.74,
#        'cost': 132.47733333333335},
#       'left': 23.5,
#       'right': 18.446666666666665},
#      'right': 42.8}}},
#   'right': {'node': {'feature': 'TAX',
#     'split': 437.0,
#     'cost': 12358.480083333334},
#    'left': {'node': {'feature': 'RM',
#      'split': 7.929,
#      'cost': 1839.4730158730156},
#     'left': {'node': {'feature': 'TAX',
#       'split': 304.0,
#       'cost': 1687.128407460545},
#      'left': {'node': {'feature': 'TAX',
#        'split': 289.0,
#        'cost': 174.93076923076913},
#       'left': 22.084615384615386,
#       'right': 27.1},
#      'right': {'node': {'feature': 'PTRATIO',
#        'split': 21.0,
#        'cost': 1217.522998696219},
#       'left': 21.1135593220339,
#       'right': 17.415384615384617}},
#     'right': 50.0},
#    'right': {'node': {'feature': 'RM',
#      'split': 6.683,
#      'cost': 6150.137210526316},
#     'left': {'node': {'feature': 'B',
#       'split': 331.29,
#       'cost': 3560.3042051282055},
#      'left': {'node': {'feature': 'RAD',
#        'split': 24.0,
#        'cost': 264.1979310344828},
#       'left': 8.1,
#       'right': 12.472413793103447},
#      'right': {'node': {'feature': 'B',
#        'split': 396.9,
#        'cost': 2899.2096296296295},
#       'left': 19.3,
#       'right': 14.403703703703705}},
#     'right': {'node': {'feature': 'LSTAT', 'split': 5.29, 'cost': 146.455},
#      'left': 50.0,
#      'right': {'node': {'feature': 'B', 'split': 179.36, 'cost': 93.388},
#       'left': 14.9,
#       'right': 22.880000000000003}}}}}]

# %%
predict(test, boston_forest)
# Out:
# 3      29.577782
# 11     21.161069
# 12     20.788955
# 25     17.941047
# 26     19.200634
# 29     21.984931
# 33     17.851606
# 35     21.994023
# 38     21.310696
# 39     26.961916
# 42     23.139038
# 48     20.391083
# 54     20.117659
# 62     22.671328
# 65     25.383332
# 66     21.638625
# 68     20.332789
# 70     23.109212
# 73     22.038041
# 76     20.698989
# 77     20.698989
# 81     24.921201
# 86     21.315259
# 87     22.349490
# 89     30.008972
# 90     23.905745
# 93     22.519726
# 99     29.758701
# 102    20.054931
# 116    20.547868
#          ...
# 389    14.583136
# 391    17.698038
# 392    12.409299
# 400    10.988080
# 404    10.460665
# 406    18.555837
# 416    13.220964
# 418    11.582451
# 419    13.172393
# 423    14.733898
# 430    15.326083
# 431    17.866480
# 435    13.145891
# 437    11.485451
# 442    16.656972
# 447    13.790386
# 448    18.155753
# 449    15.694591
# 455    16.496888
# 460    19.590317
# 462    18.421127
# 464    17.855788
# 465    19.667771
# 468    15.906042
# 473    24.048526
# 476    18.230561
# 487    19.713839
# 489    16.582135
# 491    16.959978
# 504    24.704496
# Length: 152, dtype: float64

# %%
mse(test.iloc[:, -1], predict(test, boston_forest))
# Out:
# 2287.227618258193

# %%
r_squared(test.iloc[:, -1], predict(test, boston_forest))
# Out:
# 0.822594039851509
